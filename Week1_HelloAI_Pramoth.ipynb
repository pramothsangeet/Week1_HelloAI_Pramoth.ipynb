# %% [markdown]
# <a href="https://colab.research.google.com/github/pramothsangeet/Week1_HelloAI_Pramoth.ipynb/blob/main/Week1_HelloAI_Pramoth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello AI!")
# Out:
# Hello AI!
